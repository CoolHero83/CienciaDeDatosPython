# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
x = np.random.normal(0,0.5,100)
y = np.random.normal(0,0.5,100)
x[98:] = [3,-3]
y[98:] = [3,-3]

# %%
print(x)
print(y)
# Out:
# [ 0.88202617  0.2000786   0.48936899  1.1204466   0.933779   -0.48863894
#   0.47504421 -0.0756786  -0.05160943  0.20529925  0.07202179  0.72713675
#   0.38051886  0.06083751  0.22193162  0.16683716  0.74703954 -0.10257913
#   0.15653385 -0.42704787 -1.27649491  0.3268093   0.4322181  -0.37108251
#   1.13487731 -0.72718284  0.02287926 -0.09359193  0.76638961  0.73467938
#   0.07747371  0.18908126 -0.44389287 -0.99039823 -0.17395607  0.07817448
#   0.61514534  0.60118992 -0.19366341 -0.15115138 -0.52427648 -0.71000897
#  -0.8531351   0.9753877  -0.25482609 -0.21903715 -0.62639768  0.38874518
#  -0.80694892 -0.10637014 -0.44773328  0.19345125 -0.25540257 -0.59031609
#  -0.01409111  0.21416594  0.03325861  0.15123595 -0.31716105 -0.18137058
#  -0.33623022 -0.17977658 -0.40657314 -0.8631413   0.08871307 -0.20089047
#  -0.81509917  0.23139113 -0.45364918  0.0259727   0.36454528  0.06449146
#   0.56970034 -0.61741291  0.20117082 -0.34240505 -0.43539857 -0.28942483
# ...

# %%
plt.scatter(x,y)
plt.title("Scatter Plot con Outliers")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Eliminar los outliers usando la distancia desde el centro y unbral del 95%

distancia_centro = np.sqrt(x**2+y**2)
limite = np.percentile(distancia_centro,95) # umbral del 95%

x_filtrado = x[distancia_centro <= limite]
y_filtrado = y[distancia_centro <= limite]

print(distancia_centro)
print(limite)
print(x_filtrado)
print(y_filtrado)
# Out:
# [1.29016832 0.70295453 0.80188219 1.22079199 1.10272292 1.08774254
#  0.51810922 0.38131277 0.96285515 0.76819841 0.93655286 0.85671296
#  0.57464948 0.95696825 0.2592491  0.43453274 0.88452792 0.12856714
#  0.34463925 0.62847925 1.29029582 0.63951141 0.45721875 0.75995205
#  1.1868246  0.73102155 0.2187764  0.92935652 0.83686802 0.76240415
#  0.39267654 0.32931618 0.55742445 0.9905261  0.36240278 0.34713362
#  0.67935118 0.61014459 0.27696723 0.56704727 0.91149774 0.74322204
#  0.85719572 1.02576673 1.21851594 0.52056474 0.77503881 0.68048083
#  1.04118665 0.25412535 0.44903154 0.87824211 0.45154779 0.72057148
#  0.05120336 0.39486442 0.56429891 0.56074533 0.65556251 0.28428311
#  0.41840153 0.98137307 0.62502135 0.86425066 0.61910666 0.46754057
#  0.95629198 0.80630099 0.74742978 0.1605856  0.58727209 0.17191852
#  0.71281004 0.69796653 0.5548732  0.48309832 0.59240079 0.45015159
#  0.2759415  0.02941117 0.608869   0.82188494 0.39720466 1.35125555
# ...

# %%
plt.scatter(x_filtrado, y_filtrado)
plt.title("Scatter Plot sin Outliers")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
